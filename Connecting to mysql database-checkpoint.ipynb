# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector as mc
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#mysql=mc.connect(host='MySQL81',user='root',password='15926487Root',database='sakila',use_pure=True)
mdb=mc.connect(host='localhost',user='root',password='15926487Root',database='sakila')
mdb

# %%
mycursor=mdb.cursor()

# %%
tb=pd.read_sql_query('SHOW TABLES FROM sakila',mdb)
tb
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_5068\197270873.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   tb=pd.read_sql_query('SHOW TABLES FROM sakila',mdb)
#               Tables_in_sakila
# 0                        actor
# 1                   actor_info
# 2                      address
# 3                     category
# 4                         city
# 5                      country
# 6                     customer
# 7                customer_list
# 8                         film
# 9                   film_actor
# 10               film_category
# 11                   film_list
# 12                   film_text
# 13                   inventory
# 14                    language
# 15  nicer_but_slower_film_list
# 16                     payment
# 17                      rental
# 18      sales_by_film_category
# ...

# %%
df=pd.read_sql_query('SHOW TABLES FROM sakila',mdb)
df
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_5068\2406577457.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql_query('SHOW TABLES FROM sakila',mdb)
#               Tables_in_sakila
# 0                        actor
# 1                   actor_info
# 2                      address
# 3                     category
# 4                         city
# 5                      country
# 6                     customer
# 7                customer_list
# 8                         film
# 9                   film_actor
# 10               film_category
# 11                   film_list
# 12                   film_text
# 13                   inventory
# 14                    language
# 15  nicer_but_slower_film_list
# 16                     payment
# 17                      rental
# 18      sales_by_film_category
# ...

# %%
tables =df['Tables_in_sakila']

# %%
for df in tables:
    output=pd.read_sql_query('DESCRIBE {}'.format(df),mdb)
    print(df)
    print(output,'\n')
# Out:
# actor
#          Field                  Type Null  Key               Default  \
# 0     actor_id  b'smallint unsigned'   NO  PRI                  None
# 1   first_name        b'varchar(45)'   NO                       None
# 2    last_name        b'varchar(45)'   NO  MUL                  None
# 3  last_update          b'timestamp'   NO       b'CURRENT_TIMESTAMP'
#
#                                            Extra
# 0                                 auto_increment
# 1
# 2
# 3  DEFAULT_GENERATED on update CURRENT_TIMESTAMP
#
# actor_info
#         Field                  Type Null Key Default Extra
# 0    actor_id  b'smallint unsigned'   NO        b'0'
# 1  first_name        b'varchar(45)'   NO        None
# 2   last_name        b'varchar(45)'   NO        None
# 3   film_info               b'text'  YES        None
#
# address
#          Field                  Type Null  Key               Default  \
# 0   address_id  b'smallint unsigned'   NO  PRI                  None
# ...
